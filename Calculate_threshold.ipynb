# %%
from lib_input import *
continuum_series, section_chooser = read_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-2f35ef0f2702> in <module>
# ----> 1 from lib_input import *
#       2 continuum_series, section_chooser = read_data()
#
# ~/Documents/CIMA/GITLABS/training_MOZ/lib_input.py in <module>
#      11 import matplotlib
#      12 from scipy.optimize import curve_fit
# ---> 13 from lmoments3 import distr
#      14
#      15 #---------------------------------------------------------------
#
# ~/minicondarosetta/envs/devpy/lib/python3.7/site-packages/lmoments3/distr.py in <module>
#    1371
#    1372
# -> 1373 class FrechetRGen(LmomDistrMixin, scipy.stats._continuous_distns.frechet_r_gen):
#    1374     def _lmom_fit(self, lmom_ratios):
#    1375         if lmom_ratios[1] <= 0 or lmom_ratios[2] >= 1 or lmom_ratios[2] <= -gum.lmom_ratios(nmom=3)[2]:
#
# AttributeError: module 'scipy.stats._continuous_distns' has no attribute 'frechet_r_gen'

# %%
plot_series(continuum_series,section_chooser.value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8bc06ab0c4fc> in <module>
# ----> 1 plot_series(continuum_series,section_chooser.value)
#
# NameError: name 'plot_series' is not defined

# %%
calculate_empirical_cdf(continuum_series,section_chooser.value)

# %%
extrapolate_cdf(continuum_series,section_chooser.value,Tmax=1000)
